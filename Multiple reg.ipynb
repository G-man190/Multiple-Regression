# %% [markdown]
# # Loading Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_excel('CombineML2.xlsx')
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
df.shape
# Out:
# (47878, 5)

# %% [markdown]
# # Defining x and y

# %%
x = df.drop(['PE'],axis = 1).values
y = df['PE'].values

# %% [markdown]
# # Spliting the dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.3,random_state=0)

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression
Reg = LinearRegression()
model =Reg.fit(x_train,y_train)

# %% [markdown]
# # Prediction Model

# %%
y_predicted = model.predict(x_test)
print(y_predicted)
# Out:
# [436.44787477 462.28219105 475.82629218 ... 437.7377443  433.95055917
#  430.30884458]

# %% [markdown]
# # Evalute model

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predicted)
# Out:
# 0.928909051109754

# %% [markdown]
# # Ploting

# %%
from matplotlib import pyplot as plt

plt.figure(figsize= (10,15))
plt.scatter(y_test,y_predicted)
plt.xlabel('Actual')
plt.ylabel('Predict')
plt.title('Actual vs Predict')
# Out:
# Text(0.5, 1.0, 'Actual vs Predict')

# %%
New_Data=pd.DataFrame({'Actual Data':y_test,'Predict': y_predicted, 'Difference': y_test - y_predicted})
New_Data[0:20]
# Out:
#     Actual Data     Predict  Difference
# 0        444.49  436.447875    8.042125
# 1        463.67  462.282191    1.387809
# 2        477.67  475.826292    1.843708
# 3        432.83  434.875592   -2.045592
# 4        459.59  462.213150   -2.623150
# 5        439.82  443.084470   -3.264470
# 6        427.84  428.244239   -0.404239
# 7        466.72  464.225010    2.494990
# 8        446.87  447.129889   -0.259889
# 9        448.52  451.570864   -3.050864
# 10       437.99  431.392098    6.597902
# 11       433.82  439.083086   -5.263086
# 12       433.28  433.805115   -0.525115
# 13       474.77  474.875224   -0.105224
# 14       433.72  430.165184    3.554816
# 15       473.46  470.683049    2.776951
# 16       444.71  444.171431    0.538569
# 17       434.99  429.114249    5.875751
# 18       444.07  446.894820   -2.824820
# 19       472.04  466.209425    5.830575
